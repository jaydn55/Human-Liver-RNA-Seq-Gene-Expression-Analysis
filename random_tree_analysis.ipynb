# %%
import pandas as pd
import numpy as np
import os
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA
import umap.umap_ as umap
import random
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.pipeline import Pipeline
from scipy.stats import randint, uniform

# %%
data_dir = './GSE61260/'

# %%
df = pd.read_csv(os.path.join(data_dir, 'combined.csv'))

df.head()
# Out:
#     Sample_ID  ENSG00000000003  ENSG00000000005  ENSG00000000419  \
# 0  GSM1501013         8.002176         0.175238         4.949994
# 1  GSM1501014        23.292853        -0.031148         5.657237
# 2  GSM1501015        10.557890         0.097413         7.680354
# 3  GSM1501016        10.272135         0.066298         8.835539
# 4  GSM1501017         8.290414        -0.039647         5.792685
#
#    ENSG00000000457  ENSG00000000460  ENSG00000000938  ENSG00000000971  \
# 0         3.285351         0.959516         0.672894        59.325067
# 1         2.786927         1.203578         0.358625        46.002714
# 2         2.795125         0.789783         0.733455        43.835288
# 3         3.166677         0.941032         0.755181        51.390227
# 4         2.203175         0.846344         0.612263        55.423440
#
#    ENSG00000001036  ENSG00000001084  ...  ENSG00000284032  ENSG00000284373  \
# 0         4.168056         8.104327  ...         1.222211         0.132392
# 1         4.889903         7.588060  ...         0.487849        -0.066907
# 2         5.133417         9.559194  ...         0.423539        -0.155705
# 3         4.168056        10.980774  ...         0.357365        -0.321937
# 4         3.657327        10.710821  ...         0.452607        -0.263615
#
#    ENSG00000284387  ENSG00000284395  ENSG00000284505  ENSG00000284552  \
# 0         0.491394        -0.079424        -0.255411         3.071849
# 1         0.195198         0.178077        -0.190626         1.399320
# 2         0.086307         0.230390        -0.489850         1.632879
# 3         0.232894        -0.066718        -0.233382         2.117271
# 4         0.443599         0.291308        -0.474034         3.032463
#
#           Disease  characteristics_ch1_age  characteristics_ch1_bmi  \
# 0  normal control                       70                     27.1
# 1   healthy obese                       49                     30.5
# 2  normal control                       76                     25.3
# 3  normal control                       48                     25.8
# 4  normal control                       73                     23.5
#
#    characteristics_ch1_Sex_male
# 0                             1
# 1                             0
# 2                             0
# 3                             1
# 4                             0
#
# [5 rows x 21666 columns]

# %%
le = LabelEncoder()

y = le.fit_transform(df['Disease'])

print(le.classes_)

X = df.drop(columns = ['Sample_ID', 'Disease'])
X.head()
# Out:
# ['healthy obese' 'nafld' 'nash' 'normal control' 'pbc' 'psc']
#    ENSG00000000003  ENSG00000000005  ENSG00000000419  ENSG00000000457  \
# 0         8.002176         0.175238         4.949994         3.285351
# 1        23.292853        -0.031148         5.657237         2.786927
# 2        10.557890         0.097413         7.680354         2.795125
# 3        10.272135         0.066298         8.835539         3.166677
# 4         8.290414        -0.039647         5.792685         2.203175
#
#    ENSG00000000460  ENSG00000000938  ENSG00000000971  ENSG00000001036  \
# 0         0.959516         0.672894        59.325067         4.168056
# 1         1.203578         0.358625        46.002714         4.889903
# 2         0.789783         0.733455        43.835288         5.133417
# 3         0.941032         0.755181        51.390227         4.168056
# 4         0.846344         0.612263        55.423440         3.657327
#
#    ENSG00000001084  ENSG00000001167  ...  ENSG00000283913  ENSG00000284032  \
# 0         8.104327         3.010408  ...         0.903138         1.222211
# 1         7.588060         3.464364  ...        -0.021741         0.487849
# 2         9.559194         2.829070  ...         0.424076         0.423539
# 3        10.980774         2.733645  ...         0.501803         0.357365
# 4        10.710821         2.708227  ...         0.120017         0.452607
#
#    ENSG00000284373  ENSG00000284387  ENSG00000284395  ENSG00000284505  \
# 0         0.132392         0.491394        -0.079424        -0.255411
# 1        -0.066907         0.195198         0.178077        -0.190626
# 2        -0.155705         0.086307         0.230390        -0.489850
# 3        -0.321937         0.232894        -0.066718        -0.233382
# 4        -0.263615         0.443599         0.291308        -0.474034
#
#    ENSG00000284552  characteristics_ch1_age  characteristics_ch1_bmi  \
# 0         3.071849                       70                     27.1
# 1         1.399320                       49                     30.5
# 2         1.632879                       76                     25.3
# 3         2.117271                       48                     25.8
# 4         3.032463                       73                     23.5
#
#    characteristics_ch1_Sex_male
# 0                             1
# 1                             0
# 2                             0
# 3                             1
# 4                             0
#
# [5 rows x 21664 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y)

print(X_train.shape)
print(X_test.shape)
# Out:
# (106, 21664)
# (27, 21664)

# %%
pipeline_steps = [
    ('scaler', StandardScaler()),              
    ('feature_selection', SelectKBest(f_classif, k=500)), 
    ('classifier', RandomForestClassifier(random_state=42)) 
]

pipeline = Pipeline(pipeline_steps)
print("\nDefined Pipeline:")
print(pipeline)
# Out:
# Defined Pipeline:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('feature_selection', SelectKBest(k=500)),
#                 ('classifier', RandomForestClassifier(random_state=42))])

# %%
parameters = {
    
    # Hyperparameters for SelectKBest
    'feature_selection__k': randint(50, 1000), # Number of features to select, e.g., 50 to 999

    # Hyperparameters for RandomForestClassifier
    'classifier__n_estimators': randint(100, 800),
    'classifier__max_features': ['sqrt', 'log2', 0.5, 0.7],
    'classifier__max_depth': randint(10, 50),
    'classifier__min_samples_split': randint(2, 10),
    'classifier__min_samples_leaf': randint(1, 5),
    'classifier__bootstrap': [True, False],
    'classifier__class_weight': [None, 'balanced']
}

random_search_pipeline = RandomizedSearchCV(
    estimator=pipeline,                
    param_distributions=parameters,
    n_iter=15,                        
    cv=5,                            
    scoring='accuracy',             
    verbose=2,                         
    random_state=1,                   
    n_jobs=-1                          
)

# %%
print("\nStarting RandomizedSearchCV on Pipeline...")
random_search_pipeline.fit(X_train, y_train)
print("RandomizedSearchCV on Pipeline complete.")

print("\nBest hyperparameters found for the pipeline:")
print(random_search_pipeline.best_params_)

print("\nBest cross-validation score:")
print(random_search_pipeline.best_score_)

best_pipeline_model = random_search_pipeline.best_estimator_
print("\nBest Pipeline Model:")
print(best_pipeline_model)

y_pred_tuned = best_pipeline_model.predict(X_test)

print("\n--- Evaluation of Best Tuned Pipeline on Test Set ---")
print(f"Accuracy: {accuracy_score(y_test, y_pred_tuned):.4f}")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_tuned, target_names=le.classes_))


best_scaler = best_pipeline_model.named_steps['scaler']
best_selector = best_pipeline_model.named_steps['feature_selection']
best_classifier = best_pipeline_model.named_steps['classifier']

selected_features_mask = best_selector.get_support()
selected_gene_names = X_train.columns[selected_features_mask]
print(f"\nNumber of selected genes: {len(selected_gene_names)}")
print("First 10 selected genes:", selected_gene_names[:10].tolist())
# Out:
# Starting RandomizedSearchCV on Pipeline...
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=7, classifier__n_estimators=608, feature_selection__k=440; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=7, classifier__n_estimators=608, feature_selection__k=440; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=7, classifier__n_estimators=608, feature_selection__k=440; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=7, classifier__n_estimators=608, feature_selection__k=440; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=11, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=7, classifier__n_estimators=608, feature_selection__k=440; total time=   0.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=3, classifier__n_estimators=745, feature_selection__k=897; total time=   1.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=3, classifier__n_estimators=745, feature_selection__k=897; total time=   1.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=3, classifier__n_estimators=745, feature_selection__k=897; total time=   1.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=3, classifier__n_estimators=745, feature_selection__k=897; total time=   1.2s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=22, classifier__max_features=sqrt, classifier__min_samples_leaf=4, classifier__min_samples_split=3, classifier__n_estimators=745, feature_selection__k=897; total time=   1.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=38, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=680, feature_selection__k=265; total time=   0.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=38, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=680, feature_selection__k=265; total time=   0.6s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=38, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=680, feature_selection__k=265; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=38, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=680, feature_selection__k=265; total time=   0.7s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=38, classifier__max_features=log2, classifier__min_samples_leaf=3, classifier__min_samples_split=4, classifier__n_estimators=680, feature_selection__k=265; total time=   0.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=40, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=7, classifier__n_estimators=493, feature_selection__k=57; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=40, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=7, classifier__n_estimators=493, feature_selection__k=57; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=40, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=7, classifier__n_estimators=493, feature_selection__k=57; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=40, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=7, classifier__n_estimators=493, feature_selection__k=57; total time=   0.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=40, classifier__max_features=sqrt, classifier__min_samples_leaf=3, classifier__min_samples_split=7, classifier__n_estimators=493, feature_selection__k=57; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=32, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=416, feature_selection__k=259; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=32, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=416, feature_selection__k=259; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=32, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=416, feature_selection__k=259; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=32, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=416, feature_selection__k=259; total time=   0.5s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=32, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=2, classifier__n_estimators=416, feature_selection__k=259; total time=   0.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=733, feature_selection__k=506; total time=   2.9s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=733, feature_selection__k=506; total time=   3.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=733, feature_selection__k=506; total time=   3.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=733, feature_selection__k=506; total time=   3.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=4, classifier__n_estimators=733, feature_selection__k=506; total time=   3.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=30, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=568, feature_selection__k=957; total time=   5.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=30, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=568, feature_selection__k=957; total time=   5.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=30, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=568, feature_selection__k=957; total time=   6.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=30, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=568, feature_selection__k=957; total time=   6.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=30, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=4, classifier__n_estimators=568, feature_selection__k=957; total time=   6.2s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=413, feature_selection__k=565; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=413, feature_selection__k=565; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=413, feature_selection__k=565; total time=   2.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=413, feature_selection__k=565; total time=   2.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=balanced, classifier__max_depth=13, classifier__max_features=0.5, classifier__min_samples_leaf=2, classifier__min_samples_split=3, classifier__n_estimators=413, feature_selection__k=565; total time=   2.1s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=25, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=467, feature_selection__k=788; total time=   0.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=25, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=467, feature_selection__k=788; total time=   0.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=25, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=467, feature_selection__k=788; total time=   0.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=25, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=467, feature_selection__k=788; total time=   0.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=36, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=8, classifier__n_estimators=226, feature_selection__k=329; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=25, classifier__max_features=sqrt, classifier__min_samples_leaf=1, classifier__min_samples_split=3, classifier__n_estimators=467, feature_selection__k=788; total time=   0.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=36, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=8, classifier__n_estimators=226, feature_selection__k=329; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=36, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=8, classifier__n_estimators=226, feature_selection__k=329; total time=   0.3s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=36, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=8, classifier__n_estimators=226, feature_selection__k=329; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=36, classifier__max_features=log2, classifier__min_samples_leaf=1, classifier__min_samples_split=8, classifier__n_estimators=226, feature_selection__k=329; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=37, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=266, feature_selection__k=698; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=37, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=266, feature_selection__k=698; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=37, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=266, feature_selection__k=698; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=37, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=266, feature_selection__k=698; total time=   0.4s
# [CV] END classifier__bootstrap=False, classifier__class_weight=None, classifier__max_depth=37, classifier__max_features=log2, classifier__min_samples_leaf=2, classifier__min_samples_split=5, classifier__n_estimators=266, feature_selection__k=698; total time=   0.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=20, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=187, feature_selection__k=843; total time=   1.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=20, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=187, feature_selection__k=843; total time=   1.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=20, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=187, feature_selection__k=843; total time=   1.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=20, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=187, feature_selection__k=843; total time=   1.4s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=20, classifier__max_features=0.7, classifier__min_samples_leaf=4, classifier__min_samples_split=9, classifier__n_estimators=187, feature_selection__k=843; total time=   1.5s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=721, feature_selection__k=933; total time=   4.8s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=721, feature_selection__k=933; total time=   5.1s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=721, feature_selection__k=933; total time=   5.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=721, feature_selection__k=933; total time=   5.0s
# [CV] END classifier__bootstrap=True, classifier__class_weight=None, classifier__max_depth=22, classifier__max_features=0.5, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=721, feature_selection__k=933; total time=   5.0s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=38, classifier__max_features=0.5, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=251, feature_selection__k=745; total time=   2.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=38, classifier__max_features=0.5, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=251, feature_selection__k=745; total time=   2.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=38, classifier__max_features=0.5, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=251, feature_selection__k=745; total time=   2.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=38, classifier__max_features=0.5, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=251, feature_selection__k=745; total time=   2.8s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=38, classifier__max_features=0.5, classifier__min_samples_leaf=3, classifier__min_samples_split=8, classifier__n_estimators=251, feature_selection__k=745; total time=   2.9s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=353, feature_selection__k=511; total time=   3.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=353, feature_selection__k=511; total time=   3.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=353, feature_selection__k=511; total time=   3.7s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=353, feature_selection__k=511; total time=   3.6s
# [CV] END classifier__bootstrap=False, classifier__class_weight=balanced, classifier__max_depth=23, classifier__max_features=0.7, classifier__min_samples_leaf=1, classifier__min_samples_split=2, classifier__n_estimators=353, feature_selection__k=511; total time=   3.7s
# RandomizedSearchCV on Pipeline complete.
#
# Best hyperparameters found for the pipeline:
# {'classifier__bootstrap': True, 'classifier__class_weight': 'balanced', 'classifier__max_depth': 13, 'classifier__max_features': 0.5, 'classifier__min_samples_leaf': 2, 'classifier__min_samples_split': 3, 'classifier__n_estimators': 413, 'feature_selection__k': 565}
#
# Best cross-validation score:
# 0.7445887445887445
#
# Best Pipeline Model:
# Pipeline(steps=[('scaler', StandardScaler()),
#                 ('feature_selection', SelectKBest(k=565)),
#                 ('classifier',
#                  RandomForestClassifier(class_weight='balanced', max_depth=13,
#                                         max_features=0.5, min_samples_leaf=2,
#                                         min_samples_split=3, n_estimators=413,
#                                         random_state=42))])
#
# --- Evaluation of Best Tuned Pipeline on Test Set ---
# Accuracy: 0.7037
#
# Classification Report:
#                 precision    recall  f1-score   support
#
#  healthy obese       0.60      0.60      0.60         5
#          nafld       0.20      0.25      0.22         4
#           nash       0.75      0.60      0.67         5
# normal control       0.89      1.00      0.94         8
#            pbc       1.00      0.50      0.67         2
#            psc       1.00      1.00      1.00         3
#
#       accuracy                           0.70        27
#      macro avg       0.74      0.66      0.68        27
#   weighted avg       0.73      0.70      0.71        27
#
#
# Number of selected genes: 565
# First 10 selected genes: ['ENSG00000003249', 'ENSG00000003393', 'ENSG00000003402', 'ENSG00000004864', 'ENSG00000005108', 'ENSG00000005469', 'ENSG00000005486', 'ENSG00000007202', 'ENSG00000007541', 'ENSG00000008517']

# %%
conf_matrix = confusion_matrix(y_test, y_pred_tuned)
print("\nConfusion Matrix:")
sns.heatmap(conf_matrix)
# Out:
# Confusion Matrix:
# <Axes: >
